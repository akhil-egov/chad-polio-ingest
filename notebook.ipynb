# %% [markdown]
# # Chad Polio Ingest — Extraction Notebook
#
# This notebook is a **thin wrapper** around `main.py`. All logic lives in the `.py` files.
#
# ## Before running
# Set your Elasticsearch credentials in the Jupyter kernel environment (or create a `.env` file in this directory):
#
# ```
# ES_URL=https://elasticsearch-data.es-cluster:9200
# ES_USER=your_username
# ES_PASS=your_password
# OUTPUT_DIR=output
# ```
#
# The output file will be written to `output/chad_YYYYMMDD_HHMM.xlsx`.
#
# To run only specific reports, pass a comma-separated list:
# ```python
# run(reports="coverage,activity")
# ```

# %%
from main import run
run()
